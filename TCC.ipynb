# %% [markdown]
# <a href="https://colab.research.google.com/github/brunadsfreitas/Load_of_data_set_of_final_project/blob/main/TCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import glob as g
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
somente_ti = []

# %%
path = r'/content/drive/MyDrive/Nova pasta/2020/'
filenames = g.glob(path + "/*.txt")

for file in filenames:
  file_content_list = pd.read_csv(file, sep=";")
  ti = file_content_list.loc[file_content_list['cbo2002ocupação'] > 212000]
  ti2 = ti.loc[ti['cbo2002ocupação'] < 212431]
  somente_ti.append(ti2)

# %%
somente_ti
# Out:
# [         competênciamov  região  uf  município seção  subclasse  \
#  85               202012       3  35     355030     J    6202300
#  508              202012       3  35     355030     Q    8610101
#  683              202012       3  35     355030     J    6201501
#  1110             202012       2  26     261160     N    8299799
#  1182             202012       2  29     291920     J    6201501
#  ...                 ...     ...  ..        ...   ...        ...
#  2593542          202012       2  27     270915     G    4763601
#  2593779          202012       3  33     330455     K    6499999
#  2594216          202012       2  23     230440     J    6110803
#  2594325          202012       2  29     291920     N    8220200
#  2594604          202012       4  42     421190     G    4644301
#
#           saldomovimentação  cbo2002ocupação  categoria  graudeinstrução  ...  \
#  85                      -1           212420        101                9  ...
# ...

# %%
path = r'/content/drive/MyDrive/Nova pasta/2021/'
filenames = g.glob(path + "/*.txt")

for file in filenames:
  file_content_list = pd.read_csv(file, sep=";")
  ti = file_content_list.loc[file_content_list['cbo2002ocupação'] > 212000]
  ti2 = ti.loc[ti['cbo2002ocupação'] < 212431]
  somente_ti.append(ti2)

# %%
path = r'/content/drive/MyDrive/Nova pasta/2022/'
filenames = g.glob(path + "/*.txt")

for file in filenames:
  file_content_list = pd.read_csv(file, sep=";")
  ti = file_content_list.loc[file_content_list['cbo2002ocupação'] > 212000]
  ti2 = ti.loc[ti['cbo2002ocupação'] < 212431]
  somente_ti.append(ti2)

# %%
path = r'/content/drive/MyDrive/Nova pasta/2023/'
filenames = g.glob(path + "/*.txt")

for file in filenames:
  file_content_list = pd.read_csv(file, sep=";")
  ti = file_content_list.loc[file_content_list['cbo2002ocupação'] > 212000]
  ti2 = ti.loc[ti['cbo2002ocupação'] < 212431]
  somente_ti.append(ti2)

# %%
df_full = pd.concat(somente_ti, ignore_index=True)

# %%
df_full['competênciamov'] = df_full['competênciamov'].astype(str)

# %%
df_full['mes'] = df_full['competênciamov'].str[4:6]
df_full['ano'] = df_full['competênciamov'].str[0:4]

# %%
df_full
# Out:
#        competênciamov  região  uf  município seção  subclasse  \
# 0              202012       3  35     355030     J    6202300
# 1              202012       3  35     355030     Q    8610101
# 2              202012       3  35     355030     J    6201501
# 3              202012       2  26     261160     N    8299799
# 4              202012       2  29     291920     J    6201501
# ...               ...     ...  ..        ...   ...        ...
# 886981         202212       3  33     330455     B     600001
# 886982         202301       3  35     355030     J    6202300
# 886983         202301       3  35     350570     J    6203100
# 886984         202301       3  31     317040     J    6204000
# 886985         202301       3  35     355030     K    6462000
#
#         saldomovimentação  cbo2002ocupação  categoria  graudeinstrução  ...  \
# 0                      -1           212420        101                9  ...
# ...

# %%
df_full.isnull().sum()
# Out:
# competênciamov                 0
# região                         0
# uf                             0
# município                      0
# seção                          0
# subclasse                      0
# saldomovimentação              0
# cbo2002ocupação                0
# categoria                      0
# graudeinstrução                0
# idade                         34
# horascontratuais             470
# raçacor                        0
# sexo                           0
# tipoempregador                 0
# tipoestabelecimento            0
# tipomovimentação               0
# tipodedeficiência              0
# indtrabintermitente            0
# indtrabparcial                 0
# salário                      140
# tamestabjan                    0
# indicadoraprendiz              0
# origemdainformação             0
# competênciadec                 0
# indicadordeforadoprazo         0
# unidadesaláriocódigo           0
# valorsaláriofixo           16525
# ...

# %%
df_full = df_full.drop(columns=['competênciamov', 'região','uf','competênciadec', 'competênciaexc','indicadordeexclusão', 'unidadesaláriocódigo','valorsaláriofixo' ])

# %%
df_full.dtypes
# Out:
# competênciamov             object
# região                      int64
# uf                          int64
# município                   int64
# seção                      object
# subclasse                   int64
# saldomovimentação           int64
# cbo2002ocupação             int64
# categoria                   int64
# graudeinstrução             int64
# idade                     float64
# horascontratuais           object
# raçacor                     int64
# sexo                        int64
# tipoempregador              int64
# tipoestabelecimento         int64
# tipomovimentação            int64
# tipodedeficiência           int64
# indtrabintermitente         int64
# indtrabparcial              int64
# salário                    object
# tamestabjan                 int64
# indicadoraprendiz           int64
# origemdainformação          int64
# competênciadec              int64
# indicadordeforadoprazo      int64
# unidadesaláriocódigo        int64
# ...

# %%
df_full
# Out:
#         município seção  subclasse  saldomovimentação  cbo2002ocupação  \
# 0          355030     J    6202300                 -1           212420
# 1          355030     Q    8610101                 -1           212405
# 2          355030     J    6201501                 -1           212420
# 3          261160     N    8299799                  1           212405
# 4          291920     J    6201501                  1           212405
# ...           ...   ...        ...                ...              ...
# 886981     330455     B     600001                  1           212405
# 886982     355030     J    6202300                 -1           212420
# 886983     350570     J    6203100                  1           212405
# 886984     317040     J    6204000                  1           212410
# 886985     355030     K    6462000                  1           212405
#
#         categoria  graudeinstrução  idade horascontratuais  raçacor  ...  \
# ...

# %%
df_full['salário']
# Out:
# 0          3708,68
# 1          6563,30
# 2          2400,00
# 3          2000,00
# 4          2300,00
#             ...
# 886981     5468,00
# 886982     1955,51
# 886983    13000,00
# 886984     1300,00
# 886985     6000,00
# Name: salário, Length: 886986, dtype: object

# %%
df_full['salário'] = df_full['salário'].astype(str)
df_full['idade'] = df_full['idade'].astype(str)
df_full['horascontratuais'] = df_full['horascontratuais'].astype(str)

# %%
df_full['salário'] = df_full['salário'].str.replace(',', '.')
df_full['idade'] = df_full['idade'].str.replace(',', '.')
df_full['horascontratuais'] = df_full['horascontratuais'].str.replace(',', '.')

# %%
df_full.dtypes
# Out:
# município                  int64
# seção                     object
# subclasse                  int64
# saldomovimentação          int64
# cbo2002ocupação            int64
# categoria                  int64
# graudeinstrução            int64
# idade                     object
# horascontratuais          object
# raçacor                    int64
# sexo                       int64
# tipoempregador             int64
# tipoestabelecimento        int64
# tipomovimentação           int64
# tipodedeficiência          int64
# indtrabintermitente        int64
# indtrabparcial             int64
# salário                   object
# tamestabjan                int64
# indicadoraprendiz          int64
# origemdainformação         int64
# indicadordeforadoprazo     int64
# mes                       object
# ano                       object
# dtype: object

# %%
df_full['salário'] = df_full['salário'].astype(float)
df_full['idade'] = df_full['idade'].astype(float)
df_full['horascontratuais'] = df_full['horascontratuais'].astype(float)

# %%
df_full.describe().T
# Out:
#                            count          mean           std       min  \
# município               886986.0  3.590529e+05  6.388101e+04  110002.0
# subclasse               886986.0  6.321859e+06  1.328439e+06  111301.0
# saldomovimentação       886986.0  1.306943e-01  9.914233e-01      -1.0
# cbo2002ocupação         886986.0  2.123952e+05  4.571335e+01  212205.0
# categoria               886986.0  1.144281e+02  1.086696e+02     101.0
# graudeinstrução         886986.0  1.465929e+01  2.018546e+01       1.0
# idade                   886952.0  3.185738e+01  8.560883e+00      14.0
# horascontratuais        886516.0  4.145503e+01  3.773185e+00       0.0
# raçacor                 886986.0  2.437208e+00  1.858341e+00       1.0
# sexo                    886986.0  1.412575e+00  8.092789e-01       1.0
# tipoempregador          886986.0  1.347259e-03  5.520726e-02       0.0
# tipoestabelecimento     886986.0  1.001971e+00  6.802600e-02       1.0
# ...

# %%
df_full.loc[df_full['salário'] >1000000].sort_values(by='salário', ascending=False)
# Out:
#         município seção  subclasse  saldomovimentação  cbo2002ocupação  \
# 98000      355030     N    8220200                 -1           212410
# 769187     355030     N    7810800                 -1           212215
# 562903     355030     N    7810800                  1           212215
# 150614     261160     P    8550302                  1           212205
# 342235     330455     J    6204000                  1           212405
# 745035     430510     C    2930101                 -1           212405
# 189042     351240     C    2949299                 -1           212420
# 356487     355030     N    7911200                  1           212420
# 62373      430510     C    2930101                 -1           212405
# 458295     355030     L    6821801                  1           212215
# 385155     355030     L    6821801                 -1           212215
# 341244     350570     J    6203100                  1           212405
# ...

# %%
indexNames = df_full[ df_full['salário'] > 1000000 ].index

df_full.drop(indexNames , inplace=True)

# %%
df_full.describe().T
# Out:
#                            count          mean           std       min  \
# município               886947.0  3.590527e+05  6.388097e+04  110002.0
# subclasse               886947.0  6.321902e+06  1.328374e+06  111301.0
# saldomovimentação       886947.0  1.306989e-01  9.914227e-01      -1.0
# cbo2002ocupação         886947.0  2.123952e+05  4.571168e+01  212205.0
# categoria               886947.0  1.144287e+02  1.086720e+02     101.0
# graudeinstrução         886947.0  1.465924e+01  2.018539e+01       1.0
# idade                   886913.0  3.185726e+01  8.560847e+00      14.0
# horascontratuais        886477.0  4.145503e+01  3.772979e+00       0.0
# raçacor                 886947.0  2.437217e+00  1.858341e+00       1.0
# sexo                    886947.0  1.412584e+00  8.092855e-01       1.0
# tipoempregador          886947.0  1.347318e-03  5.520848e-02       0.0
# tipoestabelecimento     886947.0  1.001971e+00  6.802749e-02       1.0
# ...

# %%
df_full['horascontratuais'].fillna(40.0, inplace=True)
df_full['salário'].fillna(4500.0, inplace=True)
df_full['idade'].fillna(30.0, inplace=True)

# %%
df_full.isnull().sum()
# Out:
# município                 0
# seção                     0
# subclasse                 0
# saldomovimentação         0
# cbo2002ocupação           0
# categoria                 0
# graudeinstrução           0
# idade                     0
# horascontratuais          0
# raçacor                   0
# sexo                      0
# tipoempregador            0
# tipoestabelecimento       0
# tipomovimentação          0
# tipodedeficiência         0
# indtrabintermitente       0
# indtrabparcial            0
# salário                   0
# tamestabjan               0
# indicadoraprendiz         0
# indicadordeforadoprazo    0
# mes                       0
# ano                       0
# dtype: int64

# %%
df_full = df_full.drop(columns=['origemdainformação'])
df_full
# Out:
#         município seção  subclasse  saldomovimentação  cbo2002ocupação  \
# 0          355030     J    6202300                 -1           212420
# 1          355030     Q    8610101                 -1           212405
# 2          355030     J    6201501                 -1           212420
# 3          261160     N    8299799                  1           212405
# 4          291920     J    6201501                  1           212405
# ...           ...   ...        ...                ...              ...
# 886981     330455     B     600001                  1           212405
# 886982     355030     J    6202300                 -1           212420
# 886983     350570     J    6203100                  1           212405
# 886984     317040     J    6204000                  1           212410
# 886985     355030     K    6462000                  1           212405
#
#         categoria  graudeinstrução  idade  horascontratuais  raçacor  ...  \
# ...

# %%
df_full = df_full.rename(columns={"município":"id_municipio","seção":"cnae_2_secao","subclasse":"cnae_2_subclasse","saldomovimentação":"saldo_movimentacao","cbo2002ocupação":"cbo_2002","categoria":"categoria","graudeinstrução":"grau_instrucao","idade":"idade","horascontratuais":"horas_contratuais","raçacor":"raca_cor","sexo":"sexo","tipoempregador":"tipo_empregador","tipoestabelecimento":"tipo_estabelecimento","tipomovimentação":"tipo_movimentacao","tipodedeficiência":"tipo_deficiencia","indtrabintermitente":"indicador_trabalho_intermitente","indtrabparcial":"indicador_trabalho_parcial","salário":"salario_mensal","tamestabjan":"tamanho_estabelecimento_janeiro","indicadoraprendiz":"indicador_aprendiz"})
df_full.head()
# Out:
#    id_municipio cnae_2_secao  cnae_2_subclasse  saldo_movimentacao  cbo_2002  \
# 0        355030            J           6202300                  -1    212420
# 1        355030            Q           8610101                  -1    212405
# 2        355030            J           6201501                  -1    212420
# 3        261160            N           8299799                   1    212405
# 4        291920            J           6201501                   1    212405
#
#    categoria  grau_instrucao  idade  horas_contratuais  raca_cor  ...  \
# 0        101               9   27.0               40.0         1  ...
# 1        101               9   28.0               44.0         1  ...
# 2        101              80   52.0               44.0         1  ...
# 3        101               8   23.0               40.0         3  ...
# 4        101               8   31.0               44.0         3  ...
#
#    tipo_movimentacao  tipo_deficiencia  indicador_trabalho_intermitente  \
# ...

# %%
df_full.hist(bins=90, grid=False, figsize=(40,20), color= '#0abab5')
plt.show()

# %%
df_full.loc[df_full['idade']==14]
# Out:
#         id_municipio cnae_2_secao  cnae_2_subclasse  saldo_movimentacao  \
# 186763        354520            C           2399199                   1
# 187874        421150            F           4120400                   1
# 189138        421105            A            133407                   1
# 189301        420550            A            133407                   1
# 189865        421550            A            133407                   1
# 190077        421150            F           4120400                   1
# 190721        421105            A            133407                   1
# 190845        420550            A            133407                   1
# 191032        421150            F           4120400                   1
# 192724        421550            A            133407                   1
# 192795        421105            A            133407                   1
# 192944        421150            F           4120400                   1
# ...

# %%
df_full.shape
# Out:
# (886947, 23)

# %%
from google.colab import files
df_full.to_csv('microdados.csv', index = False) 
files.download('microdados.csv')
